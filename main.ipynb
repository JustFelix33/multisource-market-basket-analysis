# %% [markdown]
# # Data Mining Final Project
# Kelompok 6
#
# ADHITYA SUSANTO
#
# ANDREW ALDRICH LEE
#
# FELIX OCTAVIUS XU
#
# VINCENT OLIVER LIMARUS

# %% [markdown]
# ## Libraries

# %%
# %pip install mlxtend
# %pip install pyfim
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ## Importing Data

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Retail Transactions Dataset

# %%
df_retail = pd.read_csv("../data/retail-transactions/Retail_Transactions_Dataset.csv")

# %%
df_retail['Product'] = df_retail['Product'].apply(eval)
retail_transactions = df_retail.explode('Product', ignore_index=True)

retail_transactions.to_csv("../data/retail-transactions/retail_transformed.csv", index=False)
retail_transactions.head()
# Out:
#    Transaction_ID                 Date     Customer_Name        Product  \
# 0      1000000000  2022-01-21 06:27:29      Stacey Price        Ketchup
# 1      1000000000  2022-01-21 06:27:29      Stacey Price  Shaving Cream
# 2      1000000000  2022-01-21 06:27:29      Stacey Price    Light Bulbs
# 3      1000000001  2023-03-01 13:01:21  Michelle Carlson      Ice Cream
# 4      1000000001  2023-03-01 13:01:21  Michelle Carlson           Milk
#
#    Total_Items  Total_Cost  Payment_Method           City       Store_Type  \
# 0            3       71.65  Mobile Payment    Los Angeles   Warehouse Club
# 1            3       71.65  Mobile Payment    Los Angeles   Warehouse Club
# 2            3       71.65  Mobile Payment    Los Angeles   Warehouse Club
# 3            2       25.93            Cash  San Francisco  Specialty Store
# 4            2       25.93            Cash  San Francisco  Specialty Store
#
#    Discount_Applied Customer_Category  Season               Promotion
# ...

# %% [markdown]
# ### Groceries Dataset

# %%
df_groceries = pd.read_csv("../data/groceries/groceries.csv", header=None, on_bad_lines='skip')
df_groceries
# Out:
#                         0                         1                    2  \
# 0            citrus fruit       semi-finished bread            margarine
# 1          tropical fruit                    yogurt               coffee
# 2              whole milk                       NaN                  NaN
# 3               pip fruit                    yogurt        cream cheese
# 4        other vegetables                whole milk       condensed milk
# ...                   ...                       ...                  ...
# 6101               yogurt  long life bakery product                  NaN
# 6102                 pork         frozen vegetables               pastry
# 6103            ice cream  long life bakery product  specialty chocolate
# 6104    cooking chocolate                       NaN                  NaN
# 6105  semi-finished bread             bottled water                 soda
#
#                              3
# 0                  ready soups
# ...

# %%
grocery_transactions = df_groceries.apply(lambda row: row.dropna().tolist(), axis=1).tolist()
grocery_transactions = [list(filter(None, transaction)) for transaction in grocery_transactions] 

print(grocery_transactions[:5])
print(len(grocery_transactions))
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'], ['tropical fruit', 'yogurt', 'coffee'], ['whole milk'], ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads'], ['other vegetables', 'whole milk', 'condensed milk', 'long life bakery product']]
# 6106

# %%
print(grocery_transactions)
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'], ['tropical fruit', 'yogurt', 'coffee'], ['whole milk'], ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads'], ['other vegetables', 'whole milk', 'condensed milk', 'long life bakery product'], ['rolls/buns'], ['pot plants'], ['whole milk', 'cereals'], ['beef'], ['frankfurter', 'rolls/buns', 'soda'], ['chicken', 'tropical fruit'], ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'], ['fruit/vegetable juice'], ['packaged fruit/vegetables'], ['chocolate'], ['specialty bar'], ['other vegetables'], ['butter milk', 'pastry'], ['whole milk'], ['bottled water', 'canned beer'], ['yogurt'], ['sausage', 'rolls/buns', 'soda', 'chocolate'], ['other vegetables'], ['yogurt', 'beverages', 'bottled water', 'specialty bar'], ['beef', 'grapes', 'detergent'], ['pastry', 'soda'], ['fruit/vegetable juice'], ['canned beer'], ['root vegetables', 'other vegetables', 'whole milk', 'dessert'], ['citrus fruit', 'zwieback', 'newspape
# ...

# %%
# te = TransactionEncoder()
# te_ary = te.fit(grocery_transactions).transform(grocery_transactions)
# df_groceries = pd.DataFrame(te_ary, columns=te.columns_)
# df_groceries

# %% [markdown]
# ### Store Data Dataset

# %%
df_store = pd.read_csv('../data/store-data/store_data.csv', header=None)
df_store
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
store_transactions = df_store.apply(lambda row: row.dropna().tolist(), axis=1).tolist()
store_transactions = [list(filter(None, transaction)) for transaction in store_transactions]

print(store_transactions[:5])
print(len(store_transactions))
# Out:
# [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil'], ['burgers', 'meatballs', 'eggs'], ['chutney'], ['turkey', 'avocado'], ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea']]
# 7501

# %%
print(store_transactions)
# Out:
# [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil'], ['burgers', 'meatballs', 'eggs'], ['chutney'], ['turkey', 'avocado'], ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'], ['low fat yogurt'], ['whole wheat pasta', 'french fries'], ['soup', 'light cream', 'shallot'], ['frozen vegetables', 'spaghetti', 'green tea'], ['french fries'], ['eggs', 'pet food'], ['cookies'], ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'], ['spaghetti', 'champagne', 'cookies'], ['mineral water', 'salmon'], ['mineral water'], ['shrimp', 'chocolate', 'chicken', 'honey', 'oil', 'cooking oil', 'low fat yogurt'], ['turkey', 'eggs'], ['turkey', 'fresh tuna', 'tomatoes', 'spaghetti', 'mineral water', 'black tea', 'salmon', 'eggs', 'chicken', 'extra
# ...

# %%
# te = TransactionEncoder()
# te_ary = te.fit(store_transactions).transform(store_transactions)
# df_store = pd.DataFrame(te_ary, columns=te.columns_)
# df_store

# %% [markdown]
# ### Instacart Dataset

# %%
df_instacart_products = pd.read_csv("../data/instacart-market-basket-analysis/products.csv")
df_instacart_products
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %%
unique_instacart_products = pd.unique(df_instacart_products['product_name'])
print(len(unique_instacart_products))
print(unique_instacart_products)

# %% [markdown]
# ## Data Cleaning
